# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.30.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# importing and assigning dataset
df = pd.read_csv("Nutrical Dataset.csv")
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.dtypes
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# Total Fat                        float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
# Checking the null values
df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
# reviewing summary of the dataset
df.describe(include='all')
# Out:
#             Category          Item  Serving Size     Calories  \
# count            260           260           260   260.000000
# unique             9           260           107          NaN
# top     Coffee & Tea  Egg McMuffin  16 fl oz cup          NaN
# freq              95             1            45          NaN
# mean             NaN           NaN           NaN   368.269231
# std              NaN           NaN           NaN   240.269886
# min              NaN           NaN           NaN     0.000000
# 25%              NaN           NaN           NaN   210.000000
# 50%              NaN           NaN           NaN   340.000000
# 75%              NaN           NaN           NaN   500.000000
# max              NaN           NaN           NaN  1880.000000
#
#         Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count          260.000000  260.000000                 260.000000
# unique                NaN         NaN                        NaN
# ...

# %%
df.shape
# Out:
# (260, 24)

# %%
df["Category"].unique()
# Out:
# array(['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads',
#        'Snacks & Sides', 'Desserts', 'Beverages', 'Coffee & Tea',
#        'Smoothies & Shakes'], dtype=object)

# %%
# Counting the number of items per category
sns.set(font_scale = 1)
plt.figure(figsize=(8,4))
sns.countplot(y = "Category", data = df)
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
max_values = df[['Calories','Total Fat','Carbohydrates','Dietary Fiber','Sugars','Protein','Vitamin A (% Daily Value)','Vitamin C (% Daily Value)','Calcium (% Daily Value)','Iron (% Daily Value)']].max()

print(max_values)
# Out:
# Calories                     1880.0
# Total Fat                     118.0
# Carbohydrates                 141.0
# Dietary Fiber                   7.0
# Sugars                        128.0
# Protein                        87.0
# Vitamin A (% Daily Value)     170.0
# Vitamin C (% Daily Value)     240.0
# Calcium (% Daily Value)        70.0
# Iron (% Daily Value)           40.0
# dtype: float64

# %%
total_unique_items = df['Item'].nunique()
print("Total unique items:", total_unique_items)
# Out:
# Total unique items: 260

# %%
categories_by_saturated_fat = df[ ['Category', 'Saturated Fat'] ] \
                           .groupby('Category') \
                           .sum() \
                           .sort_values('Saturated Fat', ascending=True) \
                           .head(70)

categories_by_saturated_fat

categories_by_saturated_fat.plot(kind='barh', figsize=(6,4))

plt.ylabel('Saturated Fat [grams]')
plt.title('Saturated Fat [grams] by Category');

# %%
categories_by_sodium = df[ ['Category', 'Sodium'] ] \
                           .groupby('Category') \
                           .sum() \
                           .sort_values('Sodium', ascending=True) \
                           .head(70)

categories_by_sodium

categories_by_sodium.plot(kind='barh', figsize=(8,4))

plt.ylabel('Sodium [mg]')
plt.title('Sodium [mg] by Category');

# %%
categories_by_sugars = df[ ['Category', 'Sugars'] ] \
                           .groupby('Category') \
                           .sum() \
                           .sort_values('Sugars', ascending=True) \
                           .head(70)

categories_by_sugars

categories_by_sugars.plot(kind='barh', figsize=(6,4))

plt.ylabel('Sugars [grams]')
plt.title('Sugars [grams] by Category');

# %%
# Create a histogram of the 'Calories' column
plt.figure(figsize=(6, 4))
plt.hist(df['Calories'], bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Calorie Distribution Across Menu Items')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Group the DataFrame by 'Category' and calculate the average values for each nutrient
nutritional_content = df.groupby('Category')[['Total Fat', 'Saturated Fat', 'Cholesterol', 
                                              'Sodium', 'Carbohydrates', 'Dietary Fiber', 
                                              'Sugars', 'Protein']].mean()
# Print the average values for each nutrient
print("Average Nutritional Content Across Different Categories:")
print(nutritional_content)
# Out:
# Average Nutritional Content Across Different Categories:
#                     Total Fat  Saturated Fat  Cholesterol       Sodium  \
# Category
# Beef & Pork         24.866667      10.466667    87.333333  1020.666667
# Beverages            0.092593       0.055556     0.555556    41.481481
# Breakfast           27.690476      10.654762   152.857143  1211.071429
# Chicken & Fish      26.962963       6.166667    75.370370  1257.777778
# Coffee & Tea         8.021053       4.921053    27.263158   136.894737
# Desserts             7.357143       4.285714    15.000000   117.142857
# Salads              11.750000       3.750000    51.666667   588.333333
# Smoothies & Shakes  14.125000       8.375000    45.000000   183.571429
# Snacks & Sides      10.538462       2.692308    18.461538   395.769231
#
#                     Carbohydrates  Dietary Fiber     Sugars    Protein
# Category
# Beef & Pork             40.133333       2.533333   8.800000  27.333333
# ...

# %%
# Identify menu items with the highest and lowest calorie counts
highest_calories = df[df['Calories'] == df['Calories'].max()]
lowest_calories = df[df['Calories'] == df['Calories'].min()]

# Identify menu items with high levels of saturated fat, trans fat, cholesterol, and sodium
high_saturated_fat = df[df['Saturated Fat'] == df['Saturated Fat'].max()]
high_trans_fat = df[df['Trans Fat'] == df['Trans Fat'].max()]
high_cholesterol = df[df['Cholesterol'] == df['Cholesterol'].max()]
high_sodium = df[df['Sodium'] == df['Sodium'].max()]

# Print the results
print("Menu items with the highest calorie counts:")
print(highest_calories[['Item', 'Calories']])
print("\nMenu items with the lowest calorie counts:")
print(lowest_calories[['Item', 'Calories']])
print("\nMenu items with high levels of saturated fat:")
print(high_saturated_fat[['Item', 'Saturated Fat']])
print("\nMenu items with high levels of trans fat:")
print(high_trans_fat[['Item', 'Trans Fat']])
print("\nMenu items with high levels of cholesterol:")
print(high_cholesterol[['Item', 'Cholesterol']])
print("\nMenu items with high levels of sodium:")
print(high_sodium[['Item', 'Sodium']])
# Out:
# Menu items with the highest calorie counts:
#                             Item  Calories
# 82  Chicken McNuggets (40 piece)      1880
#
# Menu items with the lowest calorie counts:
#                         Item  Calories
# 114        Diet Coke (Small)         0
# 115       Diet Coke (Medium)         0
# 116        Diet Coke (Large)         0
# 117        Diet Coke (Child)         0
# 122   Diet Dr Pepper (Small)         0
# 123  Diet Dr Pepper (Medium)         0
# 124   Diet Dr Pepper (Large)         0
# 125   Diet Dr Pepper (Child)         0
# 136      Dasani Water Bottle         0
# 137         Iced Tea (Small)         0
# 138        Iced Tea (Medium)         0
# 139         Iced Tea (Large)         0
# 140         Iced Tea (Child)         0
# 145           Coffee (Small)         0
# 146          Coffee (Medium)         0
# 147           Coffee (Large)         0
#
# Menu items with high levels of saturated fat:
#                                             Item  Saturated Fat
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(6, 4))

# Plot the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# Add title and adjust layout
plt.title('Correlation Matrix between Different Nutrients')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Define criteria for healthy and less healthy options
healthy_criteria = {
    'Calories': {'max': 500},  # Example: maximum of 500 calories
    'Saturated Fat': {'max': 10},  # Example: maximum of 10g saturated fat
    'Sodium': {'max': 500},  # Example: maximum of 500mg sodium
    # Add more criteria as needed
}

# Categorize menu options based on criteria
df['Healthiness'] = 'Healthy'
for nutrient, criteria in healthy_criteria.items():
    df.loc[df[nutrient] > criteria['max'], 'Healthiness'] = 'Less Healthy'

# Visualize the categorization results
plt.figure(figsize=(4, 2))
sns.countplot(x='Healthiness', data=df, palette='Set2')
plt.title('Categorization of Menu Options by Healthiness')
plt.xlabel('Healthiness')
plt.ylabel('Count')
plt.show()

# Provide recommendations based on categorization
healthy_options = df[df['Healthiness'] == 'Healthy']['Item'].unique()
less_healthy_options = df[df['Healthiness'] == 'Less Healthy']['Item'].unique()

print("Healthy Options:")
print(healthy_options)

print("\nLess Healthy Options:")
print(less_healthy_options)
# Out:
# Healthy Options:
# ['Hash Brown' 'Cinnamon Melts' 'Fruit & Maple Oatmeal'
#  'Fruit & Maple Oatmeal without Brown Sugar' 'Hamburger'
#  'Chicken McNuggets (4 piece)'
#  'Premium Bacon Ranch Salad (without Chicken)'
#  'Premium Southwest Salad (without Chicken)' 'Small French Fries'
#  'Medium French Fries' 'Kids French Fries' 'Side Salad' 'Apple Slices'
#  "Fruit 'n Yogurt Parfait" 'Baked Apple Pie' 'Chocolate Chip Cookie'
#  'Oatmeal Raisin Cookie' 'Kids Ice Cream Cone' 'Hot Fudge Sundae'
#  'Hot Caramel Sundae' 'Strawberry Sundae' 'Coca-Cola Classic (Small)'
#  'Coca-Cola Classic (Medium)' 'Coca-Cola Classic (Large)'
#  'Coca-Cola Classic (Child)' 'Diet Coke (Small)' 'Diet Coke (Medium)'
#  'Diet Coke (Large)' 'Diet Coke (Child)' 'Dr Pepper (Small)'
#  'Dr Pepper (Medium)' 'Dr Pepper (Large)' 'Dr Pepper (Child)'
#  'Diet Dr Pepper (Small)' 'Diet Dr Pepper (Medium)'
#  'Diet Dr Pepper (Large)' 'Diet Dr Pepper (Child)' 'Sprite (Small)'
# ...

# %%
# Checking the outliers in Sugar by plotting boxplot
plot = sns.set_style("whitegrid")
sns.boxplot(x=df['Sugars'])
# Out:
# <Axes: xlabel='Sugars'>

# %%
# Create a joint plot
joint_plot = sns.jointplot(x='Calories', y='Total Fat', data=df, kind='scatter')

# Add annotations
plt.text(500, 30, "High Calorie, High Fat", fontsize=10, color='red')
plt.text(250, 5, "Low Calorie, Low Fat", fontsize=10, color='blue')

# Show the plot
plt.show()

# %% [markdown]
# ### recommendations on how McDonald's could improve the nutritional profile of their menu
#
# '''Based on the analysis of McDonald's menu nutritional dataset, here are some recommendations on how McDonald's could improve the nutritional profile of their menu:
#
# Increase Healthy Options:
# Introduce more healthy options such as salads, grilled chicken sandwiches, and vegetable sides to provide customers with a wider selection of nutritious choices.
# Offer customizable options where customers can choose healthier ingredients and customize their meals according to their dietary preferences.
# Reduce Sodium Content:
# Reformulate recipes to reduce the sodium content of menu items, such as using herbs, spices, and other flavor-enhancing ingredients as alternatives to salt.
# Provide low-sodium alternatives or options for customers who are looking to reduce their sodium intake.
# Limit Saturated Fat and Trans Fat:
# Opt for cooking methods that minimize the use of saturated fats and trans fats, such as grilling, baking, or steaming instead of frying.
# Use healthier cooking oils and fats with lower saturated fat content, such as olive oil or canola oil.
# Offer Smaller Portion Sizes:
# Introduce smaller portion sizes for high-calorie and high-fat menu items to help customers manage their calorie intake.
# Provide combo options that include smaller portions of main items paired with healthier sides like fruit or vegetables.
# Promote Healthier Ingredients:
# Source ingredients from suppliers that prioritize quality and freshness, with a focus on whole grains, lean proteins, and fresh produce.
# Highlight healthier ingredients and nutritional information on menus and promotional materials to educate customers about the nutritional value of their choices.
# Provide Nutritional Education:
# Offer educational resources and materials to help customers make informed decisions about their food choices, including information on portion sizes, calorie counts, and nutrient content.
# Conduct awareness campaigns and promotions to promote healthier eating habits and encourage customers to make healthier choices when dining at McDonald's.
# Collaborate with Health Organizations:
# Partner with health organizations, nutritionists, and dietitians to develop and promote healthier menu options.
# Seek guidance and expertise from nutrition professionals to ensure that menu offerings align with current dietary guidelines and recommendations.
# Continuous Improvement and Innovation:
# Regularly review and update the menu to incorporate new and innovative healthier options that cater to evolving consumer preferences and dietary trends.
# Monitor customer feedback and market trends to identify opportunities for further improving the nutritional profile of menu items.
# By implementing these recommendations, McDonald's can demonstrate its commitment to promoting health and well-being while providing customers with a variety of nutritious and delicious menu options. This not only benefits customers by supporting their dietary goals but also enhances McDonald's brand reputation and competitiveness in the market.'''
